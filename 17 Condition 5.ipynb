# %%
Name = input("Enter name of employee")
Gender = input("Enter your gender(Male/Female)")
work_exp = int(input("Work experience in years: "))
base_salary = int(input("base salary: "))

gross_salary = base_salary * (1 + salary_increase_rate / 100 * work_exp)
print(gross_salary)

bonus_threshold = 2
if work_exp > 10:
    if Gender == "Female":
        if work_exp >= bonus_threshold:
            bonus_rate = 20   
            bonus = (bonus_rate / 100) * gross_salary
            print(bonus)
    elif Gender == "Male":
        if work_exp >= bonus_threshold:
            bonus_rate = 15  
            bonus = (bonus_rate / 100) * gross_salary
            print(bonus)
    print(f"Base Salary: {gross_salary}")

if work_exp > 7 and work_exp <=10 :
    if Gender == "Female":
        if work_exp >= bonus_threshold:
            bonus_rate = 18   
            bonus = (bonus_rate / 100) * gross_salary
            print(bonus)
    elif Gender == "Male":
        if work_exp >= bonus_threshold:
            bonus_rate = 15  
            bonus = (bonus_rate / 100) * gross_salary
            print(bonus)
    print(f"Base Salary: {gross_salary}")

if work_exp > 5 and work_exp <=7 :
    if Gender == "Female":
        if work_exp >= bonus_threshold:
            bonus_rate = 14   
            bonus = (bonus_rate / 100) * gross_salary
            print(bonus)
    elif Gender == "Male":
        if work_exp >= bonus_threshold:
            bonus_rate = 12  
            bonus = (bonus_rate / 100) * gross_salary
            print(bonus)
    print(f"Base Salary: {gross_salary}")


else:
    if work_exp >= bonus_threshold:
        bonus_rate = 10   
        bonus = (bonus_rate / 100) * gross_salary
        print(bonus)
        print(f"Base Salary: {gross_salary}")

# %%
name = input("enter a name of employee ")
gender = input("enter gender of employee  ")
first_base_salary = int(input("enter basic salary of employee "))
year_of_experience = eval(input("enter experience "))
salary_increase_rate = eval(input("enter incrament rate "))

gross_salary = first_base_salary * (1 + salary_increase_rate * year_of_experience)
gross_salary = int(gross_salary)
net_salary = gross_salary - (first_base_salary*0.08)
net_salary = int(net_salary)
print(gross_salary)
print(net_salary)


bonus_threshold = 2

if year_of_experience > 10:
    if gender == "female":
        bonus_rate = 0.2
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
    elif gender == "male":
        bonus_rate = 0.18
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
elif year_of_experience > 7 <= 10:
    if gender == "female":
        bonus_rate = 0.17
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
    elif gender == "male":
        bonus_rate = 0.15
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
elif year_of_experience > 5 <= 7:
    if gender == "female":
        bonus_rate = 0.2
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
    elif gender == "male":
        bonus_rate = 0.18
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
elif year_of_experience > 3 <= 5:
    if gender == "female":
        bonus_rate = 0.1
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
    elif gender == "male":
        bonus_rate = 0.08
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
else:
    if year_of_experience <= 3:
        print("there will be no bonus for employee ")
# Out:
# enter a name of employee amit
# enter gender of employee  male
# enter basic salary of employee 20000
# enter experience 3
# enter incrament rate 0.25
# 35000
# 33400
# there will be no bonus for employee

# %%
name = input("enter a name of employee ")
gender = input("enter gender of employee  ")
first_base_salary = int(input("enter basic salary of employee "))
year_of_experience = eval(input("enter experience "))
salary_increase_rate = eval(input("enter incrament rate "))

gross_salary = first_base_salary * (1 + salary_increase_rate * year_of_experience)
gross_salary = int(gross_salary)
net_salary = gross_salary - (first_base_salary*0.08)
net_salary = int(net_salary)
print(gross_salary)
print(net_salary)


bonus_threshold = 2

if year_of_experience > 10:
    if gender == "female":
        bonus_rate = 0.2
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
        if net_salary >= 100000:
            print("you will get promotion")
            if gross_salary >= 150000:
                print("You will get personal cabin")
            else:
                print("work hard to get personal cabin")
        else:
            print("Better luck next time")
    elif gender == "male":
        bonus_rate = 0.18
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
elif year_of_experience > 7 <= 10:
    if gender == "female":
        bonus_rate = 0.17
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
    elif gender == "male":
        bonus_rate = 0.15
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
elif year_of_experience > 5 <= 7:
    if gender == "female":
        bonus_rate = 0.2
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
    elif gender == "male":
        bonus_rate = 0.18
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
elif year_of_experience > 3 <= 5:
    if gender == "female":
        bonus_rate = 0.1
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
    elif gender == "male":
        bonus_rate = 0.08
        bonus = bonus_rate * gross_salary
        print(net_salary, "  ", int(bonus))
else:
    if year_of_experience <= 3:
        print("there will be no bonus for employee ")
# Out:
# enter a name of employee dipali
# enter gender of employee  female
# enter basic salary of employee 40000
# enter experience 13
# enter incrament rate 0.25
# 170000
# 166800
# 166800    34000
# you will get promotion
# You will get personal cabin
